# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexandreLouzada/exercicios-analise-dados/blob/master/analise_streaming_ALUNO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # 🎬 Estudo de Caso 3: Análise de Engajamento em Plataforma de Streaming
#
# **Contexto:** Você é Analista de Dados na StreamData. Entenda o comportamento por plano (Básico, Padrão, Premium) para retenção.
#
# **Arquivo:** `streamdata_usuarios.csv` — faça upload no Colab junto com este notebook.
#
# **Como usar:** `Arquivo > Fazer upload do notebook` + upload do CSV em `Arquivos`, execute com `Shift + Enter`, complete os `# ✏️ SEU CÓDIGO AQUI`.
#
# ---

# %% [markdown]
# ## 📥 Etapa 1: Leitura e Diagnóstico dos Dados
#
# 1. Importe `pandas` e `matplotlib.pyplot`.
# 2. Carregue `streamdata_usuarios.csv` em `df_stream`.
# 3. Exiba as 5 primeiras linhas e use `.info()`.

# %%
# ✏️ ETAPA 1 — Leitura e diagnóstico
# from google.colab import files  # descomente no Colab se precisar: uploaded = files.upload()
# ✏️ SEU CÓDIGO AQUI: imports + pd.read_csv + head() + info()

# %% [markdown]
# ## 📊 Etapa 2: Média de Horas Assistidas por Plano (Barras Horizontal)
#
# 1. Agrupe por `plano` e calcule a média de `horas_assistidas`.
# 2. Crie gráfico de barras horizontal (`plt.barh`).
# 3. Rótulos nos eixos + título + grade no eixo X.
#
# 💡 Dicas: `df.groupby("plano")["horas_assistidas"].mean()` | `plt.barh(...)` | `plt.grid(axis="x")`

# %%
# ✏️ ETAPA 2 — Horas por plano
# ✏️ SEU CÓDIGO AQUI

# %% [markdown]
# ## 📊 Etapa 3: Relação entre Satisfação e Cancelamento
#
# 1. Filtre dois grupos: `cancelou_assinatura == 'Sim'` e `== 'Não'`.
# 2. Dois histogramas sobrepostos (`plt.hist`) de `score_satisfacao` com `alpha=0.6` + legenda.
#
# 💡 Dica: `df[df["cancelou_assinatura"]=="Sim"]["score_satisfacao"]`

# %%
# ✏️ ETAPA 3 — Satisfação × Cancelamento
# ✏️ SEU CÓDIGO AQUI

# %% [markdown]
# ## 📊 Etapa 4: Distribuição dos Dispositivos Principais (Pizza)
#
# 1. Conte usuários por `dispositivo_principal` (`value_counts()`).
# 2. Pizza com `explode` na maior fatia e `%1.1f%%`.
#
# 💡 Dica: `plt.pie(valores, labels=..., autopct="%1.1f%%", explode=...)`

# %%
# ✏️ ETAPA 4 — Dispositivos
# ✏️ SEU CÓDIGO AQUI

# %% [markdown]
# ## 🏁 Checklist
#
# - [ ] Etapa 1: CSV lido + head + info
# - [ ] Etapa 2: barh com título, eixos e grade X
# - [ ] Etapa 3: 2 histogramas sobrepostos, alpha=0.6, legenda
# - [ ] Etapa 4: pizza com explode + porcentagens 1 casa
#
# Boa análise! 🎉
