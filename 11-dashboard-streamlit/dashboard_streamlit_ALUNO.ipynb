# %% [markdown]
# <a href="https://colab.research.google.com/github/seu-usuario/seu-repo/blob/main/dashboard_streamlit_ALUNO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # 📊 Desenvolvimento e Publicação de um Dashboard Interativo
#
# **Objetivo:** Construir um painel de BI (filtros, métricas, gráficos) e publicá-lo na nuvem.
#
# ---

# %% [markdown]
# ## 🟢 Fase 1 — Estrutura Básica e Otimização
#
# **P1.** Importe `streamlit` e `pandas`; `st.title('Dashboard de Vendas')`.
# **P2.** Crie `carregar_dados()` lendo `vendas.csv`.
# **P3.** Decore com `@st.cache_data`.

# %%
# ✏️ FASE 1 — imports, função cache e título
# ✏️ SEU CÓDIGO AQUI

# %% [markdown]
# ## 🟡 Fase 2 — Layout e Filtros Laterais
#
# **P1.** `st.sidebar.title('Filtros')`.
# **P2.** `st.sidebar.multiselect(...)` com as categorias.
# **P3.** Filtrar `df` com `isin()`.

# %%
# ✏️ FASE 2 — sidebar, multiselect e filtro
# ✏️ SEU CÓDIGO AQUI

# %% [markdown]
# ## 🔵 Fase 3 — Métricas e Visualização
#
# **P1.** `st.columns([1, 1])`.
# **P2.** `st.metric('Receita Total', ...)` e `st.metric('Total de Pedidos', ...)`.
# **P3.** `st.tabs(['Evolução Mensal', 'Tabela de Dados'])`.
# **P4.** Agrupar por mês e `st.area_chart`.
# **P5.** `st.dataframe` + `st.download_button`.

# %%
# ✏️ FASE 3 — colunas, métricas, abas, área e download
# ✏️ SEU CÓDIGO AQUI

# %% [markdown]
# ## 🚀 Fase 4 — Publicação na Nuvem
#
# **Home (resposta em texto):** explique o passo a passo do deploy no Streamlit Community Cloud (1 repositório GitHub com `meu_dashboard.py` + `vendas.csv`; 2 arquivo `requirements.txt` com `streamlit`, `pandas`, `matplotlib`; 3 conectar conta GitHub em share.streamlit.io; 4 selecionar o repo e apontar o arquivo principal).

# %%
# ✏️ (Opcional) Cole aqui o código completo do seu meu_dashboard.py para revisão
