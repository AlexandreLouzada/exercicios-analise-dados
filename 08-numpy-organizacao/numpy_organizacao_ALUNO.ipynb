# %% [markdown]
# <a href="https://colab.research.google.com/github/seu-usuario/seu-repo/blob/main/numpy_organizacao_ALUNO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # 🛠️ Organização e Transformação de Dados com NumPy
#
# **Contexto:** Preparação de bases e álgebra linear: sequências, tipagem, reshape, cópias, broadcasting, `argsort` e `linalg.solve`.
#
# **Colab:** `Arquivo > Fazer upload do notebook`, execute com `Shift + Enter`, complete os `# ✏️ SEU CÓDIGO AQUI`.
#
# ---

# %%
import numpy as np

# %% [markdown]
# ## 🟢 Nível 1 — Geração de Sequências e Tipagem de Dados (Básico)
#
# **P1.** `np.arange(1, 31)` — 30 dias
# **P2.** `np.linspace(20000, 30000, 5)` — 5 metas
# **P3.** `np.array([10.5, 20.1, 30.9]).astype(int)`
# **P4.** Últimos 5 dias invertidos: `dias_mes[-5:][::-1]`

# %%
# ✏️ NÍVEL 1 — Sequências e tipagem
# P1 a P4
# ✏️ SEU CÓDIGO AQUI

# %% [markdown]
# ## 🟡 Nível 2 — Redimensionamento e Proteção de Dados (Intermediário)
#
# **P1.** `np.array([...12 visitas...]).reshape(4, 3)`
# **P2.** `np.vstack([sem1, sem2])`
# **P3.** Fatia do 1º trimestre com `.copy()`
# **P4.** `matriz.ravel()`
#
# 💡 Visões compartilham memória; cópias não. Sem `.copy()`, alterar a fatia muda o original.

# %%
# ✏️ NÍVEL 2 — Reshape, stack, cópia, ravel
# ✏️ SEU CÓDIGO AQUI

# %% [markdown]
# ## 🔵 Nível 3 — Ranking, Broadcasting e Resolução de Sistemas (Avançado)
#
# **P1.** `np.argsort(np.array([85, 92, 78, 95, 88]))`
# **P2.** `precos[:, np.newaxis]` para virar coluna; combine com descontos via broadcasting
# **P3.** Sistema: `A = np.array([[2, 1], [1, -1]])`, `b = np.array([500, 100])`, `np.linalg.solve(A, b)`

# %%
# ✏️ NÍVEL 3 — argsort, newaxis, linalg.solve
# ✏️ SEU CÓDIGO AQUI

# %% [markdown]
# ## 🏁 Checklist
#
# - [ ] N1: arange + linspace + astype + slicing invertido
# - [ ] N2: reshape + vstack + copy + ravel
# - [ ] N3: argsort + newaxis + solve
#
# Boa análise! 🎉
