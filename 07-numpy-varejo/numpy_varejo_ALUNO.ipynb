# %% [markdown]
# <a href="https://colab.research.google.com/github/seu-usuario/seu-repo/blob/main/numpy_varejo_ALUNO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # 🏪 Análise de Dados no Varejo com NumPy
#
# **Missão:** Insights de varejo com NumPy — vectorização, máscaras, NaN, `np.where`, categorias e destaques de marketing.
#
# **Colab:** `Arquivo > Fazer upload do notebook`, execute com `Shift + Enter`, complete os `# ✏️ SEU CÓDIGO AQUI`.
#
# ---

# %%
import numpy as np

# %% [markdown]
# ## 🟢 Nível 1 — Faturamento Semanal e Filtros (Básico)
#
# **P1.** `np.array([150, 120, 90, 210, 300, 250, 180])`
# **P2.** Multiplique por 50 (vetorização)
# **P3.** Máscara `> 200` para extrair dias de pico

# %%
# ✏️ NÍVEL 1 — Faturamento semanal
# P1: criar o array pecas_vendidas
# ✏️ SEU CÓDIGO AQUI

# P2: faturamento = pecas_vendidas * 50
# ✏️ SEU CÓDIGO AQUI

# P3: máscara booleana e filtro dos dias de pico
# ✏️ SEU CÓDIGO AQUI

# %% [markdown]
# ## 🟡 Nível 2 — Múltiplas Filiais e Falhas de Sistema (Intermediário)
#
# **P1.** Matriz 2D lojas × dias (`Loja A: [200, 220, np.nan, 250]`, `Loja B: [150, 180, 160, 190]`, `Loja C: [300, 310, 290, 330]`)
# **P2.** Total por loja: `np.nansum(..., axis=1)`
# **P3.** Média geral ignorando NaN: `np.nanmean`
# **P4.** `np.where(vendas >= 200, 'Meta Atingida', 'Abaixo')`

# %%
# ✏️ NÍVEL 2 — Filiais
# P1: criar a matriz 2D
# ✏️ SEU CÓDIGO AQUI

# P2: soma por loja (axis=1) — cuidado com NaN!
# ✏️ SEU CÓDIGO AQUI

# P3: média geral ignorando NaN
# ✏️ SEU CÓDIGO AQUI

# P4: matriz condicional da meta (200)
# ✏️ SEU CÓDIGO AQUI

# %% [markdown]
# ## 🔵 Nível 3 — Categorização e Destaques de Marketing (Avançado)
#
# **P1.** `rng = np.random.default_rng(42)`; amostra de 50 em `['Eletrônicos', 'Roupas', 'Casa']` com `rng.choice(..., size=50)`
# **P2.** `np.unique(..., return_counts=True)`
# **P3.** Faturamento: `[12000, 45000, 23000, 89000, 31000]` → `np.argmax`

# %%
# ✏️ NÍVEL 3 — Categorias e marketing
# P1: gerador com semente + amostra
# ✏️ SEU CÓDIGO AQUI

# P2: contagem por departamento
# ✏️ SEU CÓDIGO AQUI

# P3: campanha campeã (índice do maior)
# ✏️ SEU CÓDIGO AQUI

# %% [markdown]
# ## 🏁 Checklist
#
# - [ ] N1: array + `*50` + máscara `>200`
# - [ ] N2: soma axis=1, `nanmean`, `np.where` meta
# - [ ] N3: `default_rng` + `unique` + `argmax`
#
# Boa análise! 🎉
