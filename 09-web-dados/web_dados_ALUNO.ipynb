# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexandreLouzada/exercicios-analise-dados/blob/master/web_dados_ALUNO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # 🌐 Explorando Dados na Web com Python
#
# **Objetivo:** Requisições HTTP com `requests`, tratamento de JSON/erros/arquivos binários e web scraping ético com `BeautifulSoup`.
#
# **Colab:** `Arquivo > Fazer upload do notebook`, execute com `Shift + Enter`, complete os `# ✏️ SEU CÓDIGO AQUI`.
#
# 💡 Se faltar o `bs4`, rode `!pip install beautifulsoup4` em uma célula.
#
# ---

# %%
import requests
import pandas as pd
import io
from bs4 import BeautifulSoup

# %% [markdown]
# ## 🟢 Nível 1 — URLs, Parâmetros e Cabeçalhos (Básico)
#
# **1.1** GET em `https://jsonplaceholder.typicode.com/posts`
# **1.2** `params` para filtrar (ex: `userId=2`, `_limit=3`)
# **1.3** `headers` com User-Agent do seu projeto
# **1.4** Imprimir `status_code` e `resposta.url`, com `timeout=10`

# %%
# ✏️ NÍVEL 1 — requisição GET com params, headers e timeout
# ✏️ SEU CÓDIGO AQUI

# %% [markdown]
# ## 🟡 Nível 2 — JSON, Erros e Arquivos Binários (Intermediário)
#
# **2.1** Loop em 3 CEPs: `https://viacep.com.br/ws/{cep}/json/` → `.json()` → DataFrame
# **2.2** Função de download com `try/except` + `raise_for_status()`
# **2.3** Baixar `https://picsum.photos/400/400` → `resposta.content` → arquivo `.jpg` (`wb`)

# %%
# ✏️ 2.1 — ViaCEP → DataFrame
# ✏️ SEU CÓDIGO AQUI

# %%
# ✏️ 2.2 — função de download segura
# ✏️ SEU CÓDIGO AQUI

# %%
# ✏️ 2.3 — download da imagem em bytes
# ✏️ SEU CÓDIGO AQUI

# %% [markdown]
# ## 🔵 Nível 3 — Webscraping e Ética (Avançado)
#
# **3.1** Requisição ao `robots.txt` do site-alvo
# **3.2** `https://books.toscrape.com/` → BeautifulSoup `'html.parser'` → título e preço dos 5 primeiros livros (`article.product_pod`, `.h3.a['title']`, `p.price_color`)
# **3.3** Salvar em CSV com Pandas
# **3.4** Wikipedia com tabela → `pd.read_html(io.StringIO(html))`

# %%
# ✏️ 3.1 — robots.txt
# ✏️ SEU CÓDIGO AQUI

# %%
# ✏️ 3.2 — extrair 5 livros com BeautifulSoup
# ✏️ SEU CÓDIGO AQUI

# %%
# ✏️ 3.3 — salvar CSV
# ✏️ SEU CÓDIGO AQUI

# %%
# ✏️ 3.4 — tabela da Wikipedia via read_html + StringIO
# ✏️ SEU CÓDIGO AQUI

# %% [markdown]
# ## 🏁 Checklist
#
# - [ ] N1: GET + params + headers + status + url + timeout
# - [ ] N2: DataFrame de CEPs; download seguro; imagem `.jpg`
# - [ ] N3: robots.txt; 5 livros → CSV; `read_html`
#
# Boa análise! 🎉
